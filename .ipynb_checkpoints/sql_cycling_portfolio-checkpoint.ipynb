# %% [markdown]
# # Cycling Collisions in California #
#
# In this project, I use Jupyter Notebooks and SQLite to analyze traffic collisions in California involving at least one bicycle.
#
# The data has been requested and cleaned by Alex Gude and uploaded to Kaggle. The original data comes from the California Highway Patrol and covers collisions from January 1st, 2001 until mid-October, 2020.
#
# ## Setting up SQL interface with Jupyter Lab ##

# %%
# %load_ext sql

# %% [markdown]
# Data source:
#
# https://www.kaggle.com/alexgude/california-traffic-collision-data-from-switrs

# %% [markdown]
# Loading the files:

# %%
# %sql sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite

# %% [markdown]
# ## Exploring the data ##

# %% [markdown]
# View variables in the collisions and parties tables

# %%
# %sql PRAGMA table_info(collisions);
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(0, 'case_id', 'TEXT', 0, None, 0),
#  (1, 'jurisdiction', 'INT', 0, None, 0),
#  (2, 'officer_id', 'TEXT', 0, None, 0),
#  (3, 'reporting_district', 'TEXT', 0, None, 0),
#  (4, 'chp_shift', 'TEXT', 0, None, 0),
#  (5, 'population', 'TEXT', 0, None, 0),
#  (6, 'county_city_location', 'TEXT', 0, None, 0),
#  (7, 'special_condition', 'TEXT', 0, None, 0),
#  (8, 'beat_type', 'TEXT', 0, None, 0),
#  (9, 'chp_beat_type', 'TEXT', 0, None, 0),
#  (10, 'city_division_lapd', 'TEXT', 0, None, 0),
#  (11, 'chp_beat_class', 'TEXT', 0, None, 0),
#  (12, 'beat_number', 'TEXT', 0, None, 0),
#  (13, 'primary_road', 'TEXT', 0, None, 0),
#  (14, 'secondary_road', 'TEXT', 0, None, 0),
#  (15, 'distance', 'REAL', 0, None, 0),
#  (16, 'direction', 'TEXT', 0, None, 0),
#  (17, 'intersection', 'INT', 0, None, 0),
#  (18, 'weather_1', 'TEXT', 0, None, 0),
#  (19, 'weather_2', 'TEXT', 0, None, 0),
#  (20, 'state_highway_indicator', 'INT', 0, None, 0),
#  (21, 'caltrans_county', 'TEXT', 0, None, 0),
#  (22, 'caltrans_district', 'INT', 0, None, 0),
#  (23, 'state_route', 'INT', 0, None, 0),
#  (24, 'route_suffix', 'TEXT', 0, None, 0),
#  (25, 'postmile_prefix', 'TEXT', 0, None, 0),
#  (26, 'postmile', 'REAL', 0, None, 0),
#  (27, 'location_type', 'TEXT', 0, None, 0),
#  (28, 'ramp_intersection', 'INT', 0, None, 0),
#  (29, 'side_of_highway', 'TEXT', 0, None, 0),
#  (30, 'tow_away', 'INT', 0, None, 0),
#  (31, 'collision_severity', 'TEXT', 0, None, 0),
#  (32, 'killed_victims', 'INT', 0, None, 0),
#  (33, 'injured_victims', 'INT', 0, None, 0),
#  (34, 'party_count', 'INT', 0, None, 0),
#  (35, 'primary_collision_factor', 'TEXT', 0, None, 0),
#  (36, 'pcf_violation_code', 'TEXT', 0, None, 0),
#  (37, 'pcf_violation_category', 'TEXT', 0, None, 0),
#  (38, 'pcf_violation', 'INT', 0, None, 0),
#  (39, 'pcf_violation_subsection', 'TEXT', 0, None, 0),
#  (40, 'hit_and_run', 'TEXT', 0, None, 0),
#  (41, 'type_of_collision', 'TEXT', 0, None, 0),
#  (42, 'motor_vehicle_involved_with', 'TEXT', 0, None, 0),
#  (43, 'pedestrian_action', 'TEXT', 0, None, 0),
#  (44, 'road_surface', 'TEXT', 0, None, 0),
#  (45, 'road_condition_1', 'TEXT', 0, None, 0),
#  (46, 'road_condition_2', 'TEXT', 0, None, 0),
#  (47, 'lighting', 'TEXT', 0, None, 0),
#  (48, 'control_device', 'TEXT', 0, None, 0),
#  (49, 'chp_road_type', 'TEXT', 0, None, 0),
#  (50, 'pedestrian_collision', 'INT', 0, None, 0),
#  (51, 'bicycle_collision', 'INT', 0, None, 0),
#  (52, 'motorcycle_collision', 'INT', 0, None, 0),
#  (53, 'truck_collision', 'INT', 0, None, 0),
#  (54, 'not_private_property', 'INT', 0, None, 0),
#  (55, 'alcohol_involved', 'INT', 0, None, 0),
#  (56, 'statewide_vehicle_type_at_fault', 'TEXT', 0, None, 0),
#  (57, 'chp_vehicle_type_at_fault', 'TEXT', 0, None, 0),
#  (58, 'severe_injury_count', 'INT', 0, None, 0),
#  (59, 'other_visible_injury_count', 'INT', 0, None, 0),
#  (60, 'complaint_of_pain_injury_count', 'INT', 0, None, 0),
#  (61, 'pedestrian_killed_count', 'INT', 0, None, 0),
#  (62, 'pedestrian_injured_count', 'INT', 0, None, 0),
#  (63, 'bicyclist_killed_count', 'INT', 0, None, 0),
#  (64, 'bicyclist_injured_count', 'INT', 0, None, 0),
#  (65, 'motorcyclist_killed_count', 'INT', 0, None, 0),
#  (66, 'motorcyclist_injured_count', 'INT', 0, None, 0),
#  (67, 'primary_ramp', 'TEXT', 0, None, 0),
#  (68, 'secondary_ramp', 'TEXT', 0, None, 0),
#  (69, 'latitude', 'REAL', 0, None, 0),
#  (70, 'longitude', 'REAL', 0, None, 0),
#  (71, 'collision_date', 'TEXT', 0, None, 0),
#  (72, 'collision_time', 'TEXT', 0, None, 0),
#  (73, 'process_date', 'TEXT', 0, None, 0)]

# %%
# %sql PRAGMA table_info(parties);
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(0, 'id', 'INT', 0, None, 0),
#  (1, 'case_id', 'TEXT', 0, None, 0),
#  (2, 'party_number', 'INT', 0, None, 0),
#  (3, 'party_type', 'TEXT', 0, None, 0),
#  (4, 'at_fault', 'INT', 0, None, 0),
#  (5, 'party_sex', 'TEXT', 0, None, 0),
#  (6, 'party_age', 'INT', 0, None, 0),
#  (7, 'party_sobriety', 'TEXT', 0, None, 0),
#  (8, 'party_drug_physical', 'TEXT', 0, None, 0),
#  (9, 'direction_of_travel', 'TEXT', 0, None, 0),
#  (10, 'party_safety_equipment_1', 'TEXT', 0, None, 0),
#  (11, 'party_safety_equipment_2', 'TEXT', 0, None, 0),
#  (12, 'financial_responsibility', 'TEXT', 0, None, 0),
#  (13, 'hazardous_materials', 'TEXT', 0, None, 0),
#  (14, 'cellphone_use', 'TEXT', 0, None, 0),
#  (15, 'school_bus_related', 'TEXT', 0, None, 0),
#  (16, 'oaf_violation_code', 'TEXT', 0, None, 0),
#  (17, 'oaf_violation_category', 'TEXT', 0, None, 0),
#  (18, 'oaf_violation_section', 'INT', 0, None, 0),
#  (19, 'oaf_violation_suffix', 'TEXT', 0, None, 0),
#  (20, 'other_associate_factor_1', 'TEXT', 0, None, 0),
#  (21, 'other_associate_factor_2', 'TEXT', 0, None, 0),
#  (22, 'party_number_killed', 'INT', 0, None, 0),
#  (23, 'party_number_injured', 'INT', 0, None, 0),
#  (24, 'movement_preceding_collision', 'TEXT', 0, None, 0),
#  (25, 'vehicle_year', 'INT', 0, None, 0),
#  (26, 'vehicle_make', 'TEXT', 0, None, 0),
#  (27, 'statewide_vehicle_type', 'TEXT', 0, None, 0),
#  (28, 'chp_vehicle_type_towing', 'TEXT', 0, None, 0),
#  (29, 'chp_vehicle_type_towed', 'TEXT', 0, None, 0),
#  (30, 'party_race', 'TEXT', 0, None, 0)]

# %% [markdown]
# How many cyclist crashes happen each year?

# %% [markdown]
# What percentage of cycling collisions resulted in injury or fatality by year?

# %%
# %sql SELECT strftime('%Y', collision_date) AS year, \
SUM(bicycle_collision), \
ROUND(SUM(killed_victims) * 1.0 / SUM(bicycle_collision), 4) AS rate_fatalities, \
ROUND(SUM(injured_victims) * 1.0 / SUM(bicycle_collision), 4) AS rate_injuries \
FROM collisions \
WHERE bicycle_collision = 1 AND Collision_Date <= '2020-12-31' \
GROUP BY year \
ORDER BY rate_fatalities;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [('2010', 13966, 0.0079, 0.933),
#  ('2009', 13445, 0.0081, 0.9186),
#  ('2011', 15041, 0.0094, 0.9288),
#  ('2001', 12720, 0.0096, 0.9211),
#  ('2002', 12355, 0.0097, 0.9166),
#  ('2004', 12452, 0.01, 0.9162),
#  ('2012', 15276, 0.01, 0.9363),
#  ('2008', 13079, 0.0101, 0.9238),
#  ('2014', 14285, 0.0101, 0.94),
#  ('2003', 12204, 0.0104, 0.9168),
#  ('2007', 11781, 0.0106, 0.9234),
#  ('2005', 11731, 0.0113, 0.9205),
#  ('2013', 14542, 0.0113, 0.9385),
#  ('2015', 13958, 0.0113, 0.9327),
#  ('2020', 5418, 0.0129, 0.9247),
#  ('2006', 10975, 0.0132, 0.9223),
#  ('2017', 12398, 0.0132, 0.9254),
#  ('2016', 13039, 0.0133, 0.9235),
#  ('2019', 11192, 0.0138, 0.927),
#  ('2018', 12166, 0.0147, 0.9225)]

# %% [markdown]
# The deadliest year for bicycle collisions (in terms of the rate of fatalities) was 2018. Most collisions (> 90%) result in injury, but that's likely due to bias of the dataset. The police are more likely to be notified when accidents are more severe.
#
# How severe are bicycle collisions?

# %%
# %sql SELECT collision_severity, \
    SUM(bicycle_collision) as n_bike_collisions, \
    ROUND(SUM(bicycle_collision) * 1.0 / 252023, 4) AS rate \
FROM collisions \
WHERE bicycle_collision = 1 AND Collision_Date <= '2020-12-31' \
GROUP BY collision_severity \
ORDER BY n_bike_collisions DESC;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [('other injury', 118113, 0.4687),
#  ('pain', 90389, 0.3587),
#  ('property damage only', 23307, 0.0925),
#  ('severe injury', 17478, 0.0694),
#  ('fatal', 2736, 0.0109)]

# %% [markdown]
# Compare totals for collisions and parties tables

# %%
# %sql select sum(collisions.bicycle_collision), \
(select count(parties.party_type) \
from parties \
where party_type = 'bicyclist') as sum_party_type \
from collisions;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(252023, 256305)]

# %% [markdown]
# Since the number of bicycle collisions is less than the number of parties involving bicyclists, it seems like over 4,000 collisions since 2001 involved more than one cyclist.
#
# How many crashes involved bicycles but no cars?

# %%
#collisions with motor vehicle and bicycle:

# %sql SELECT COUNT(*) FROM collisions \
        WHERE motor_vehicle_involved_with = 'bicycle';
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(222476,)]

# %%
# number of all bike collisions minus collisions with bike and motor vehicle

# %sql SELECT \
    (SELECT SUM(bicycle_collision) FROM collisions) - \
    (SELECT COUNT(*) FROM collisions \
        WHERE motor_vehicle_involved_with = 'bicycle') as bike_no_car;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(29547,)]

# %%
# view examples of bike_no_car

# %sql SELECT * FROM collisions \
        WHERE bicycle_collision = 1 AND \
        motor_vehicle_involved_with != 'bicycle' \
        Limit 5;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [('3526265', 5600, '3364', None, '5', '6', '5607', '0', '0', 'not chp', None, 'not chp', None, 'THOUSAND OAKS BL', 'MAEGAN PL', 2.0, 'west', 0, 'clear', None, 0, None, None, None, None, None, None, None, None, None, 1, 'pain', 0, 1, 2, 'vehicle code violation', None, 'dui', 23152, 'A', 'not hit and run', 'hit object', 'fixed object', 'no pedestrian involved', 'dry', 'normal', None, 'dark with street lights', 'none', '0', None, 1, None, None, 1, 1, 'passenger car', '01', 0, 0, 1, 0, 0, 0, 1, 0, 0, None, None, None, None, '2008-01-03', '17:50:00', '2008-08-13'),
#  ('3526312', 3009, '9207', '136', '5', '6', '3009', '0', '0', 'not chp', None, 'not chp', '00R', 'HARBOR BL', 'QUATRO AV', 345.0, 'north', 0, 'clear', None, 0, None, None, None, None, None, None, None, None, None, 1, 'other injury', 0, 1, 7, 'vehicle code violation', None, 'dui', 23152, 'A', 'not hit and run', 'rear end', 'other motor vehicle', 'no pedestrian involved', 'dry', 'normal', None, 'dark with street lights', 'obscured', '0', None, 1, None, None, 1, 1, 'passenger car', '01', 0, 1, 0, 0, 0, 0, 1, 0, 0, None, None, None, None, '2008-01-01', '00:40:00', '2008-08-14'),
#  ('3560150', 4316, '10329', '28', '5', '6', '4316', '0', '0', 'not chp', None, 'not chp', '002', 'CENTRAL EXPWY', 'FAIROAKS AV', 528.0, 'west', 0, 'cloudy', None, 0, None, None, None, None, None, None, None, None, None, 0, 'other injury', 0, 1, 1, 'vehicle code violation', None, 'speeding', 22350, None, 'not hit and run', 'hit object', 'fixed object', 'no pedestrian involved', 'wet', 'normal', None, 'daylight', 'none', '0', None, 1, None, None, 1, None, 'bicycle', '04', 0, 1, 0, 0, 0, 0, 1, 0, 0, None, None, None, None, '2008-01-10', '15:42:00', '2008-08-11'),
#  ('3565150', 3019, '1839', None, '5', '7', '3019', '0', '0', 'not chp', None, 'not chp', None, 'SUNFLOWER AV', 'FAIRVIEW RD', 0.0, None, 1, 'clear', None, 0, None, None, None, None, None, None, None, None, None, 0, 'pain', 0, 1, 2, 'vehicle code violation', None, 'traffic signals and signs', 21453, 'A', 'not hit and run', 'pedestrian', 'other motor vehicle', 'no pedestrian involved', 'dry', 'normal', None, 'daylight', 'functioning', '0', None, 1, None, None, 1, None, None, None, 0, 0, 1, 0, 0, 0, 1, 0, 0, None, None, None, None, '2008-01-01', '09:28:00', '2008-08-11'),
#  ('3565192', 5001, '627', None, '5', '4', '5001', '0', '0', 'not chp', None, 'not chp', '001', 'RICHLAND AV', 'HATCH RD', 0.0, None, 1, 'cloudy', 'raining', 0, None, None, None, None, None, None, None, None, None, 0, 'pain', 0, 1, 2, 'vehicle code violation', None, 'traffic signals and signs', 21453, 'A', 'felony', 'broadside', 'pedestrian', 'no pedestrian involved', 'wet', 'normal', None, 'daylight', 'functioning', '0', None, 1, None, None, 1, 1, 'passenger car', None, 0, 0, 1, 0, 0, 0, 1, 0, 0, None, None, None, None, '2008-01-10', '08:13:00', '2008-08-13')]

# %% [markdown]
# On what days of the week do most bicycle collisions occur?

# %%
# %sql SELECT SUM(bicycle_collision), \
    CASE WHEN strftime('%w', collision_date) = '0' THEN 'Sunday' \
    WHEN strftime('%w', collision_date) = '1' THEN 'Monday' \
    WHEN strftime('%w', collision_date) = '2' THEN 'Tuesday' \
    WHEN strftime('%w', collision_date) = '3' THEN 'Wednesday' \
    WHEN strftime('%w', collision_date) = '4' THEN 'Thursday' \
    WHEN strftime('%w', collision_date) = '5' THEN 'Friday' \
    ELSE 'Saturday' END AS day_of_week \
from collisions \
WHERE bicycle_collision = 1 AND Collision_Date <= '2020-12-31' \
GROUP BY day_of_week \
ORDER BY SUM(bicycle_collision) DESC;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(40133, 'Wednesday'),
#  (39969, 'Tuesday'),
#  (39571, 'Thursday'),
#  (39169, 'Friday'),
#  (36594, 'Monday'),
#  (31174, 'Saturday'),
#  (25413, 'Sunday')]

# %% [markdown]
# More collisions occur in the middle of the week, perhaps because more people are out on the road then.
#
# During which months of the year do most bicycle collisions occur?

# %%
# %sql SELECT SUM(bicycle_collision), \
    CASE WHEN strftime('%m', collision_date) = '01' THEN 'Jan' \
    WHEN strftime('%m', collision_date) = '02' THEN 'Feb' \
    WHEN strftime('%m', collision_date) = '03' THEN 'Mar' \
    WHEN strftime('%m', collision_date) = '04' THEN 'Apr' \
    WHEN strftime('%m', collision_date) = '05' THEN 'May' \
    WHEN strftime('%m', collision_date) = '06' THEN 'Jun' \
    WHEN strftime('%m', collision_date) = '07' THEN 'Jul' \
    WHEN strftime('%m', collision_date) = '08' THEN 'Aug' \
    WHEN strftime('%m', collision_date) = '09' THEN 'Sep' \
    WHEN strftime('%m', collision_date) = '10' THEN 'Oct' \
    WHEN strftime('%m', collision_date) = '11' THEN 'Nov' \
    ELSE 'Dec' END AS day_of_week \
from collisions \
WHERE bicycle_collision = 1 AND Collision_Date <= '2020-12-31' \
GROUP BY day_of_week \
ORDER BY SUM(bicycle_collision) DESC;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(24849, 'Sep'),
#  (24205, 'Oct'),
#  (23636, 'Jul'),
#  (23443, 'Aug'),
#  (23130, 'May'),
#  (22992, 'Jun'),
#  (20906, 'Apr'),
#  (20348, 'Mar'),
#  (18933, 'Nov'),
#  (17210, 'Feb'),
#  (17188, 'Jan'),
#  (15183, 'Dec')]

# %% [markdown]
# What types of weather conditions correlate with collisions involving bicycles?

# %%
# %sql SELECT weather_1, \
SUM(bicycle_collision) \
FROM collisions \
WHERE bicycle_collision = 1 AND Collision_Date <= '2020-12-31' \
GROUP BY weather_1 \
ORDER BY SUM(bicycle_collision) DESC;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [('clear', 222256),
#  ('cloudy', 23463),
#  ('raining', 3661),
#  (None, 1768),
#  ('fog', 482),
#  ('other', 272),
#  ('wind', 81),
#  ('snowing', 40)]

# %% [markdown]
# Unsurprisingly, the fewest accidents occur on snowy days, probably because fewer people are cycling then. Similarly, more people are out on clear days and in warmer months, increasing the chances of collision.
#
# How often are cyclists the party at fault?
#
# Each year:

# %%
# %sql SELECT strftime('%Y', collision_date) AS year, \
    count(distinct collisions.case_id) as n_bike_collisions, \
    SUM(CASE WHEN statewide_vehicle_type = 'bicycle' AND at_fault = 1 THEN 1 ELSE null END) as n_bike_at_fault, \
    ROUND(SUM(CASE WHEN statewide_vehicle_type = 'bicycle' AND at_fault = 1 THEN 1 ELSE null END) * 1.0 / count(distinct collisions.case_id), 4) as rate_bike_at_fault \
FROM collisions \
LEFT JOIN parties \
ON collisions.case_id = parties.case_id \
WHERE bicycle_collision = 1 AND \
    Collision_Date <= '2020-12-31'\
GROUP BY year;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [('2001', 12720, 7568, 0.595),
#  ('2002', 12355, 5945, 0.4812),
#  ('2003', 12204, 6406, 0.5249),
#  ('2004', 12452, 7192, 0.5776),
#  ('2005', 11731, 6656, 0.5674),
#  ('2006', 10975, 6064, 0.5525),
#  ('2007', 11781, 6601, 0.5603),
#  ('2008', 13079, 7312, 0.5591),
#  ('2009', 13445, 7556, 0.562),
#  ('2010', 13966, 7931, 0.5679),
#  ('2011', 15041, 8643, 0.5746),
#  ('2012', 15276, 8823, 0.5776),
#  ('2013', 14542, 8204, 0.5642),
#  ('2014', 14285, 7845, 0.5492),
#  ('2015', 13958, 7530, 0.5395),
#  ('2016', 13039, 7040, 0.5399),
#  ('2017', 12398, 6631, 0.5348),
#  ('2018', 12166, 6519, 0.5358),
#  ('2019', 11192, 5893, 0.5265),
#  ('2020', 5418, 2842, 0.5245)]

# %% [markdown]
# In total:

# %%
# %sql SELECT count(distinct collisions.case_id) as n_bike_collisions, \
    SUM(CASE WHEN statewide_vehicle_type = 'bicycle' AND at_fault = 1 THEN 1 ELSE null END) as n_bike_at_fault, \
    ROUND(SUM(CASE WHEN statewide_vehicle_type = 'bicycle' AND at_fault = 1 THEN 1 ELSE null END) * 1.0 / count(distinct collisions.case_id), 4) as rate_bike_at_fault \
FROM collisions \
LEFT JOIN parties \
ON collisions.case_id = parties.case_id \
WHERE bicycle_collision = 1 AND \
    Collision_Date <= '2020-12-31';
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(252023, 139201, 0.5523)]

# %% [markdown]
# Interestingly, cyclists seem to be at fault more than half of the time.
#
# Could this be because cyclists are more often reckless? Or perhaps because they are more often too injured to give their perspective in police reports? The data doesn't provide info on who filed reports, but we can look at the categories of collision types as well as what kind of injuries at fault cyclists sustained.
#
# What kinds of injuries are reported on collisions involving bicycles?
# What type of collision occurred?
# Which partied filed a report?

# %%
# %sql SELECT type_of_collision, \
    SUM(bicycle_collision) as n_bike_collisions, \
    ROUND(SUM(bicycle_collision) * 1.0 / 252023, 4) AS rate \
FROM collisions \
WHERE bicycle_collision = 1 AND Collision_Date <= '2020-12-31' \
GROUP BY type_of_collision \
ORDER BY n_bike_collisions DESC;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [('broadside', 109646, 0.4351),
#  ('other', 64903, 0.2575),
#  ('sideswipe', 26230, 0.1041),
#  ('rear end', 11377, 0.0451),
#  ('pedestrian', 10930, 0.0434),
#  ('head-on', 10699, 0.0425),
#  ('hit object', 6673, 0.0265),
#  ('overturned', 5817, 0.0231),
#  (None, 5748, 0.0228)]

# %%
# %sql SELECT count(distinct collisions.case_id) as n_bike_collisions, \
    SUM(CASE WHEN victim_role = 4 THEN 1 ELSE null END) as n_bike_victim \
FROM collisions \
LEFT JOIN victims \
ON collisions.case_id = victims.case_id \
WHERE bicycle_collision = 1 AND \
    Collision_Date <= '2020-12-31';
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(252023, 226502)]

# %%
# %sql SELECT victim_degree_of_injury, \
    count(distinct collisions.case_id) as n_bike_collisions, \
    SUM(CASE WHEN victim_role = 4 THEN 1 ELSE null END) as n_bike_victims \
FROM collisions \
LEFT JOIN victims \
ON collisions.case_id = victims.case_id \
WHERE bicycle_collision = 1 AND \
    Collision_Date <= '2020-12-31'\
GROUP BY victim_degree_of_injury;
# Out:
#  * sqlite:///C://Users//rache//Downloads//data_science//ca-traffic-collisions/switrs.sqlite
# Done.
# [(None, 20588, None),
#  ('5', 1291, 1288),
#  ('6', 4206, 4172),
#  ('7', 1783, 1741),
#  ('complaint of pain', 90779, 88078),
#  ('killed', 2736, 2693),
#  ('no injury', 32711, None),
#  ('other visible injury', 114763, 112640),
#  ('severe injury', 16242, 15890)]

# %% [markdown]
# **Oustanding questions**
#
# Difference between the sexes? Party at fault or victim?
#
# Differences between age groups? Party at fault or victim?
#
# Where do most bicycle collisions take place? Population-wise.
